# %% [markdown]
# # Count or Frequency Encoding

# %% [markdown]
# Count or frequency encoding: Replace the categories by the count of the observations that show that category in
# the dataset. Similarly, we can replace the category by the frequency -or percentage- of observations in the
# dataset.

# %%
import pandas as pd

# %%
train_set = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', header = None,index_col=None)
train_set.head()
# Out:
#    0                  1       2           3   4                    5   \
# 0  39          State-gov   77516   Bachelors  13        Never-married
# 1  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 2  38            Private  215646     HS-grad   9             Divorced
# 3  53            Private  234721        11th   7   Married-civ-spouse
# 4  28            Private  338409   Bachelors  13   Married-civ-spouse
#
#                    6               7       8        9     10  11  12  \
# 0        Adm-clerical   Not-in-family   White     Male  2174   0  40
# 1     Exec-managerial         Husband   White     Male     0   0  13
# 2   Handlers-cleaners   Not-in-family   White     Male     0   0  40
# 3   Handlers-cleaners         Husband   Black     Male     0   0  40
# 4      Prof-specialty            Wife   Black   Female     0   0  40
#
#                13      14
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
columns = [1,2,5,6,7,8,9,13] #selecting categorical columns

# %%
train_set = train_set[columns]
train_set
# Out:
#                       1       2                    5                   6   \
# 0              State-gov   77516        Never-married        Adm-clerical
# 1       Self-emp-not-inc   83311   Married-civ-spouse     Exec-managerial
# 2                Private  215646             Divorced   Handlers-cleaners
# 3                Private  234721   Married-civ-spouse   Handlers-cleaners
# 4                Private  338409   Married-civ-spouse      Prof-specialty
# ...                  ...     ...                  ...                 ...
# 32556            Private  257302   Married-civ-spouse        Tech-support
# 32557            Private  154374   Married-civ-spouse   Machine-op-inspct
# 32558            Private  151910              Widowed        Adm-clerical
# 32559            Private  201490        Never-married        Adm-clerical
# 32560       Self-emp-inc  287927   Married-civ-spouse     Exec-managerial
#
#                    7       8        9               13
# ...

# %%
# now adding feature names to all columns
train_set.columns=['Employment','Degree','Status','Designation','family_job','Race','Sex','Country']
train_set
# Out:
#               Employment  Degree               Status         Designation  \
# 0              State-gov   77516        Never-married        Adm-clerical
# 1       Self-emp-not-inc   83311   Married-civ-spouse     Exec-managerial
# 2                Private  215646             Divorced   Handlers-cleaners
# 3                Private  234721   Married-civ-spouse   Handlers-cleaners
# 4                Private  338409   Married-civ-spouse      Prof-specialty
# ...                  ...     ...                  ...                 ...
# 32556            Private  257302   Married-civ-spouse        Tech-support
# 32557            Private  154374   Married-civ-spouse   Machine-op-inspct
# 32558            Private  151910              Widowed        Adm-clerical
# 32559            Private  201490        Never-married        Adm-clerical
# 32560       Self-emp-inc  287927   Married-civ-spouse     Exec-managerial
#
#            family_job    Race      Sex         Country
# ...

# %%
# printing no. of unique labels in features

for feature in train_set.columns[:]:
    print(feature,":",len(train_set[feature].unique()),'labels')
# Out:
# Employment : 9 labels
# Degree : 21648 labels
# Status : 7 labels
# Designation : 15 labels
# family_job : 6 labels
# Race : 5 labels
# Sex : 2 labels
# Country : 42 labels

# %%
# converting country names to dictionary with their value counts

country_map=train_set['Country'].value_counts().to_dict()
country_map
# Out:
# {' United-States': 29170,
#  ' Mexico': 643,
#  ' ?': 583,
#  ' Philippines': 198,
#  ' Germany': 137,
#  ' Canada': 121,
#  ' Puerto-Rico': 114,
#  ' El-Salvador': 106,
#  ' India': 100,
#  ' Cuba': 95,
#  ' England': 90,
#  ' Jamaica': 81,
#  ' South': 80,
#  ' China': 75,
#  ' Italy': 73,
#  ' Dominican-Republic': 70,
#  ' Vietnam': 67,
#  ' Guatemala': 64,
#  ' Japan': 62,
#  ' Poland': 60,
#  ' Columbia': 59,
#  ' Taiwan': 51,
#  ' Haiti': 44,
#  ' Iran': 43,
#  ' Portugal': 37,
#  ' Nicaragua': 34,
#  ' Peru': 31,
#  ' Greece': 29,
#  ' France': 29,
#  ' Ecuador': 28,
#  ' Ireland': 24,
#  ' Hong': 20,
#  ' Cambodia': 19,
#  ' Trinadad&Tobago': 19,
#  ' Laos': 18,
#  ' Thailand': 18,
#  ' Yugoslavia': 16,
#  ' Outlying-US(Guam-USVI-etc)': 14,
#  ' Honduras': 13,
#  ' Hungary': 13,
#  ' Scotland': 12,
#  ' Holand-Netherlands': 1}

# %%
train_set['Country']=train_set['Country'].map(country_map) #mapping
train_set.head(20)
# Out:
#            Employment  Degree                  Status         Designation  \
# 0           State-gov   77516           Never-married        Adm-clerical
# 1    Self-emp-not-inc   83311      Married-civ-spouse     Exec-managerial
# 2             Private  215646                Divorced   Handlers-cleaners
# 3             Private  234721      Married-civ-spouse   Handlers-cleaners
# 4             Private  338409      Married-civ-spouse      Prof-specialty
# 5             Private  284582      Married-civ-spouse     Exec-managerial
# 6             Private  160187   Married-spouse-absent       Other-service
# 7    Self-emp-not-inc  209642      Married-civ-spouse     Exec-managerial
# 8             Private   45781           Never-married      Prof-specialty
# 9             Private  159449      Married-civ-spouse     Exec-managerial
# 10            Private  280464      Married-civ-spouse     Exec-managerial
# 11          State-gov  141297      Married-civ-spouse      Prof-specialty
# ...

# %% [markdown]
# # Advantages
# 1. Easy To Use
# 2. Not increasing feature space
#
# # Disadvantages
# 1. It will provide same weight if the frequencies are same
